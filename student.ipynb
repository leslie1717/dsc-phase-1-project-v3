# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Leslie Siron
# * Student pace: self paced
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %% [markdown]
# Project Overview
# For this project, you will use data cleaning, imputation, analysis, and visualization to generate insights for a business stakeholder.
#
# Business Problem
# Your company is expanding in to new industries to diversify its portfolio. Specifically, they are interested in purchasing and operating airplanes for commercial and private enterprises, but do not know anything about the potential risks of aircraft. You are charged with determining which aircraft are the lowest risk for the company to start this new business endeavor. You must then translate your findings into actionable insights that the head of the new aviation division can use to help decide which aircraft to purchase.
#
# The Data
# In the data folder is a dataset from the National Transportation Safety Board that includes aviation accident data from 1962 to 2023 about civil aviation accidents and selected incidents in the United States and international waters.
#
# It is up to you to decide what data to use, how to deal with missing values, how to aggregate the data, and how to visualize it in an interactive dashboard.
#
# Key Points
# Your analysis should yield three concrete business recommendations. The key idea behind dealing with missing values, aggregating and visualizaing data is to help your organization make data driven decisions. You will relate your findings to business intelligence by making recommendations for how the business should move forward with the new aviation opportunity.
#
# Communicating about your work well is extremely important. Your ability to provide value to an organization - or to land a job there - is directly reliant on your ability to communicate with them about what you have done and why it is valuable. Create a storyline your audience (the head of the aviation division) can follow by walking them through the steps of your process, highlighting the most important points and skipping over the rest.
#
# Use plenty of visualizations. Visualizations are invaluable for exploring your data and making your findings accessible to a non-technical audience. Spotlight visuals in your presentation, but only ones that relate directly to your recommendations. Simple visuals are usually best (e.g. bar charts and line graphs), and don't forget to format them well (e.g. labels, titles).

# %%
import pandas as pd

# %%
# Import 'bp.txt' file
df = pd.read_csv('data/Aviation_Data.csv', dtype=object)
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country   Latitude   Longitude Airport.Code  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
# ...

# %%
assert type(df) == pd.DataFrame

# %%
df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %% [markdown]
# IS THIS OK THAT THEY ARE ALL OBJECTS? DO I NEED TO CHANGE EACH COLUMN TYPE? I HAD AN ERROR INPUTING THE DATA SO I JUST CALLED ALL COLUMNS OBJECTS

# %%
#pd.to_datetime(df['Event.Date']).head()

# %%
#type(['Event.Date'])

# %%
#pd.to_datetime(df['Publication.Date'], dayfirst=True).head()

# %%
df = df.set_index(['Event.Id'])
df.head()
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
#
#                        Location        Country   Latitude   Longitude  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States        NaN         NaN
# 20001218X45447   BRIDGEPORT, CA  United States        NaN         NaN
# 20061025X01555    Saltville, VA  United States  36.922223  -81.878056
# 20001218X45448       EUREKA, CA  United States        NaN         NaN
# 20041105X01764       Canton, OH  United States        NaN         NaN
#
#                Airport.Code Airport.Name Injury.Severity  ...  \
# Event.Id                                                  ...
# ...

# %%
column_summary = df['Aircraft.Category'].describe()
column_summary
value_counts = df['Aircraft.Category'].value_counts()
print(value_counts)
# Out:
# Aircraft.Category
# Airplane             27617
# Helicopter            3440
# Glider                 508
# Balloon                231
# Gyrocraft              173
# Weight-Shift           161
# Powered Parachute       91
# Ultralight              30
# Unknown                 14
# WSFT                     9
# Powered-Lift             5
# Blimp                    4
# UNK                      2
# Rocket                   1
# ULTR                     1
# Name: count, dtype: int64

# %%
value_counts = df['Total.Fatal.Injuries'].value_counts()
print(value_counts)
# Out:
# Total.Fatal.Injuries
# 0.0      59675
# 1.0       8883
# 2.0       5173
# 3.0       1589
# 4.0       1103
#          ...
# 156.0        1
# 68.0         1
# 31.0         1
# 115.0        1
# 176.0        1
# Name: count, Length: 125, dtype: int64

# %%
df["Year"] = df["Event.Date"].apply(lambda x : str(x)[:4])
df.head()
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
#
#                        Location        Country   Latitude   Longitude  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States        NaN         NaN
# 20001218X45447   BRIDGEPORT, CA  United States        NaN         NaN
# 20061025X01555    Saltville, VA  United States  36.922223  -81.878056
# 20001218X45448       EUREKA, CA  United States        NaN         NaN
# 20041105X01764       Canton, OH  United States        NaN         NaN
#
#                Airport.Code Airport.Name Injury.Severity  ... Air.carrier  \
# Event.Id                                                  ...
# ...

# %% [markdown]
# WHY COULD I GET THE YEAR OUT OF THE DF BUT BELOW I COULDN'T GET THE YEAR OUT OF DF2?

# %%
df2 = df[["Accident.Number", "Year", "Country", "Aircraft.Category", "Make", "Model", "Purpose.of.flight", "Total.Fatal.Injuries", "Total.Uninjured"]]
df2.head()
# Out:
#                Accident.Number  Year        Country Aircraft.Category  \
# Event.Id
# 20001218X45444      SEA87LA080  1948  United States               NaN
# 20001218X45447      LAX94LA336  1962  United States               NaN
# 20061025X01555      NYC07LA005  1974  United States               NaN
# 20001218X45448      LAX96LA321  1977  United States               NaN
# 20041105X01764      CHI79FA064  1979  United States               NaN
#
#                     Make     Model Purpose.of.flight Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444   Stinson     108-3          Personal                  2.0
# 20001218X45447     Piper  PA24-180          Personal                  4.0
# 20061025X01555    Cessna      172M          Personal                  3.0
# 20001218X45448  Rockwell       112          Personal                  2.0
# 20041105X01764    Cessna       501          Personal                  1.0
#
#                Total.Uninjured
# Event.Id
# 20001218X45444             0.0
# ...

# %%
nan_count = df2['Aircraft.Category'].isna().sum()

print(nan_count)
# Out:
# 58061

# %%
Helico

# %%
WANT TO LOOK AT ALL AIRCRAFT CATS THAT ARE NAN AND SEE IF I CAN CATEGORIZE THEM BASED ON MAKE
# Out:
#   Cell In[34], line 1
#     WANT TO LOOK AT ALL AIRCRAFT CATS THAT ARE NAN AND SEE IF I CAN CATEGORIZE THEM BASED ON MAKE
#          ^
# SyntaxError: invalid syntax

# %%
AirCatNaN = df2["Aircraft.Category" == "Nan"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 AirCatNaN = df2["Aircraft.Category" == "Nan"]
#
# ...

# %% [markdown]
# MAKE EVENT DATE JUS TTHE FIRST 4 DIGITS

# %%
df2.loc[:4, 'Event.Date'] = 'Year'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df2.loc[:4, 'Event.Date'] = 'Year'
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:881, in _LocationIndexer.__setitem__(self, key, value)
#     879 else:
#     880     key = com.apply_if_callable(key, self.obj)
# --> 881 indexer = self._get_setitem_indexer(key)
#     882 self._has_valid_setitem_indexer(key)
#     884 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:758, in _LocationIndexer._get_setitem_indexer(self, key)
#     755 if isinstance(key, tuple):
#     756     with suppress(IndexingError):
#     757         # suppress "Too many indexers"
# --> 758         return self._convert_tuple(key)
#     760 if isinstance(key, range):
#     761     # GH#45479 test_loc_setitem_range_key
# ...

# %%
df2['Event.Date'] = df2['Event.Date'].astype(str)
# Out:
# /var/folders/q0/wm4_mkcj3lbg416jpgm0p14m0000gn/T/ipykernel_70644/890240813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event.Date'] = df2['Event.Date'].astype(str)

# %%
df2["Year"] = df2["Event.Date"].apply(lambda x : str(x)[:4])
# Out:
# /var/folders/q0/wm4_mkcj3lbg416jpgm0p14m0000gn/T/ipykernel_70644/756675135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Year"] = df2["Event.Date"].apply(lambda x : str(x)[:4])

# %%
df2["Year"] = (df2["Event.Date"]).loc[:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df2["Year"] = (df2["Event.Date"]).loc[:4]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1373, in _LocIndexer._getitem_axis(self, key, axis)
#    1371 if isinstance(key, slice):
#    1372     self._validate_key(key, axis)
# -> 1373     return self._get_slice_axis(key, axis=axis)
#    1374 elif com.is_bool_indexer(key):
#    1375     return self._getbool_axis(key, axis=axis)
#
# ...
